# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %load_ext autoreload
# %autoreload 2

import numpy as np
from matplotlib import pyplot as plt

import sys
sys.path.append('..')
from BBH_kick_sim import Simulator

import pickle
import glob

# %% [markdown]
# ## Uniform spin, No mass sort

# %%
fileloc = './sp_U_sm_0/'
files = glob.glob(fileloc + '/*.pkl')
[print(f) for f in files];
# Out:
# ./sp_U_sm_0/output_10.pkl
# ./sp_U_sm_0/output_9.pkl
# ./sp_U_sm_0/output_8.pkl
# ./sp_U_sm_0/output_5.pkl
# ./sp_U_sm_0/output_4.pkl
# ./sp_U_sm_0/output_6.pkl
# ./sp_U_sm_0/output_7.pkl
# ./sp_U_sm_0/output_3.pkl
# ./sp_U_sm_0/output_2.pkl
# ./sp_U_sm_0/output_1.pkl

# %%
spUsm0_mass = []
spUsm0_spin = []
spUsm0_vel = []
spUsm0_LargestBHs = []
for fname in files:
    with open(fname,'rb') as f:
        params,seeds,all_gcs = pickle.load(f)
        
    #These files are BIG. Only do one at a time
    for gc in all_gcs:
        bhs = gc.ejected+gc.BHs
        spUsm0_mass.extend([b.m for b in bhs]) 
        spUsm0_spin.extend([b.s_mag for b in bhs])
        spUsm0_vel.extend([np.sqrt(np.sum(np.square(b.v))) for b in bhs])
        maxi = np.argmax([b.m for b in bhs])
        spUsm0_LargestBHs.append(bhs[maxi])
    del all_gcs

# %%
n,_,_=plt.hist(spUsm0_mass,bins='auto',density=True)
plt.title('BH Final Mass distribution')
plt.xlabel('BH mass [M_sun]')
plt.show()

# %%
n,_,_=plt.hist(spUsm0_spin,bins='auto',density=True)
plt.title('BH Final Spin distribution')
plt.xlabel('Dimentionless BH spin')
plt.show()

# %%
n,_,_=plt.hist(spUsm0_vel,bins='auto',density=True)
plt.title('BH Final velocity')
plt.xlabel('Velocity [km/s]')
plt.show()

# %%
maxi = np.argmax([b.m for b in spUsm0_LargestBHs])
spUsm0_LargestBHs[maxi].printTree(params=['m','s_mag','v_imag'])
# Out:
# [m=341.064,s_mag=0.903,v_imag=1370.032]
# ├── [m=224.838,s_mag=0.913,v_imag=64.024]
# │   ├── [m=178.614,s_mag=0.883,v_imag=60.656]
# │   │   ├── [m=97.365,s_mag=0.722,v_imag=22.558]
# │   │   │   ├── [m=51.345,s_mag=0.172,v_imag=0.0]
# │   │   │   └── [m=51.333,s_mag=0.067,v_imag=0.0]
# │   │   └── [m=96.865,s_mag=0.711,v_imag=22.584]
# │   │       ├── [m=51.021,s_mag=0.128,v_imag=0.0]
# │   │       └── [m=51.013,s_mag=0.091,v_imag=0.0]
# │   └── [m=60.689,s_mag=0.739,v_imag=17.385]
# │       ├── [m=58.891,s_mag=0.746,v_imag=65.513]
# │       │   ├── [m=31.132,s_mag=0.262,v_imag=0.0]
# │       │   └── [m=31.128,s_mag=0.193,v_imag=0.0]
# │       └── [m=2.576,s_mag=0.715,v_imag=65.49]
# │           ├── [m=1.358,s_mag=0.052,v_imag=0.0]
# │           └── [m=1.358,s_mag=0.231,v_imag=0.0]
# └── [m=146.293,s_mag=0.897,v_imag=61.286]
#     ├── [m=93.241,s_mag=0.883,v_imag=24.111]
#     │   ├── [m=68.59,s_mag=0.807,v_imag=61.359]
#     │   │   ├── [m=36.579,s_mag=0.236,v_imag=0.0]
#     │   │   └── [m=36.573,s_mag=0.798,v_imag=0.0]
#     │   └── [m=31.259,s_mag=0.855,v_imag=25.031]
#     │       ├── [m=27.924,s_mag=0.775,v_imag=36.412]
#     │       │   ├── [m=14.835,s_mag=0.289,v_imag=0.0]
#     │       │   └── [m=14.808,s_mag=0.326,v_imag=0.0]
#     │       └── [m=4.267,s_mag=0.734,v_imag=36.189]
#     │           ├── [m=2.253,s_mag=0.129,v_imag=0.0]
#     │           └── [m=2.253,s_mag=0.21,v_imag=0.0]
#     └── [m=65.08,s_mag=0.797,v_imag=39.108]
#         ├── [m=61.871,s_mag=0.757,v_imag=45.168]
#         │   ├── [m=32.749,s_mag=0.352,v_imag=0.0]
#         │   └── [m=32.749,s_mag=0.239,v_imag=0.0]
#         └── [m=4.152,s_mag=0.721,v_imag=45.049]
#             ├── [m=2.19,s_mag=0.174,v_imag=0.0]
#             └── [m=2.188,s_mag=0.057,v_imag=0.0]

# %% [markdown]
# ## Uniform spin, Yes mass sort

# %%
fileloc = './sp_U_sm_1/'
files = glob.glob(fileloc + '/*.pkl')
[print(f) for f in files];
# Out:
# ./sp_U_sm_1/output_10.pkl
# ./sp_U_sm_1/output_9.pkl
# ./sp_U_sm_1/output_8.pkl
# ./sp_U_sm_1/output_5.pkl
# ./sp_U_sm_1/output_4.pkl
# ./sp_U_sm_1/output_6.pkl
# ./sp_U_sm_1/output_7.pkl
# ./sp_U_sm_1/output_3.pkl
# ./sp_U_sm_1/output_2.pkl
# ./sp_U_sm_1/output_1.pkl

# %%
spUsm1_mass = []
spUsm1_spin = []
spUsm1_vel = []
spUsm1_LargestBHs = []
for fname in files:
    with open(fname,'rb') as f:
        params,seeds,all_gcs = pickle.load(f)
        
    #These files are BIG. Only do one at a time
    for gc in all_gcs:
        bhs = gc.ejected+gc.BHs
        spUsm1_mass.extend([b.m for b in bhs]) 
        spUsm1_spin.extend([b.s_mag for b in bhs])
        spUsm1_vel.extend([np.sqrt(np.sum(np.square(b.v))) for b in bhs])
        maxi = np.argmax([b.m for b in bhs])
        spUsm1_LargestBHs.append(bhs[maxi])
    del all_gcs

# %%
n,_,_=plt.hist(spUsm1_mass,bins='auto',density=True)
plt.title('BH Final Mass distribution')
plt.xlabel('BH mass [M_sun]')
plt.show()

# %%
n,_,_=plt.hist(spUsm1_spin,bins='auto',density=True)
plt.title('BH Final Spin distribution')
plt.xlabel('Dimentionless BH spin')
plt.show()

# %%
n,_,_=plt.hist(spUsm1_vel,bins='auto',density=True)
plt.title('BH Final velocity')
plt.xlabel('Velocity [km/s]')
plt.show()

# %%
maxi = np.argmax([b.m for b in spUsm1_LargestBHs])
spUsm1_LargestBHs[maxi].printTree(params=['m','s_mag','v_imag'])
# Out:
# [m=357.803,s_mag=0.797,v_imag=2256.845]
# ├── [m=276.174,s_mag=0.928,v_imag=28.987]
# │   ├── [m=192.433,s_mag=0.9,v_imag=20.5]
# │   │   ├── [m=173.852,s_mag=0.852,v_imag=43.794]
# │   │   │   ├── [m=164.117,s_mag=0.815,v_imag=30.079]
# │   │   │   │   ├── [m=96.437,s_mag=0.46,v_imag=11.208]
# │   │   │   │   │   ├── [m=94.655,s_mag=0.53,v_imag=1.17]
# │   │   │   │   │   │   ├── [m=93.0,s_mag=0.609,v_imag=7.461]
# │   │   │   │   │   │   │   ├── [m=91.415,s_mag=0.69,v_imag=5.781]
# │   │   │   │   │   │   │   │   ├── [m=48.05,s_mag=0.024,v_imag=0.0]
# │   │   │   │   │   │   │   │   └── [m=48.049,s_mag=0.001,v_imag=0.0]
# │   │   │   │   │   │   │   └── [m=2.616,s_mag=0.794,v_imag=6.062]
# │   │   │   │   │   │   │       ├── [m=1.393,s_mag=0.377,v_imag=0.0]
# │   │   │   │   │   │   │       └── [m=1.393,s_mag=0.357,v_imag=0.0]
# │   │   │   │   │   │   └── [m=2.545,s_mag=0.698,v_imag=12.946]
# │   │   │   │   │   │       ├── [m=1.339,s_mag=0.014,v_imag=0.0]
# │   │   │   │   │   │       └── [m=1.339,s_mag=0.061,v_imag=0.0]
# │   │   │   │   │   └── [m=2.527,s_mag=0.876,v_imag=14.618]
# │   │   │   │   │       ├── [m=1.371,s_mag=0.721,v_imag=0.0]
# │   │   │   │   │       └── [m=1.371,s_mag=0.637,v_imag=0.0]
# │   │   │   │   └── [m=78.887,s_mag=0.743,v_imag=9.906]
# │   │   │   │       ├── [m=77.023,s_mag=0.781,v_imag=15.666]
# │   │   │   │       │   ├── [m=40.933,s_mag=0.307,v_imag=0.0]
# │   │   │   │       │   └── [m=40.919,s_mag=0.335,v_imag=0.0]
# │   │   │   │       └── [m=2.908,s_mag=0.704,v_imag=16.058]
# │   │   │   │           ├── [m=1.532,s_mag=0.024,v_imag=0.0]
# │   │   │   │           └── [m=1.529,s_mag=0.092,v_imag=0.0]
# │   │   │   └── [m=12.751,s_mag=0.74,v_imag=55.808]
# │   │   │       ├── [m=6.74,s_mag=0.076,v_imag=0.0]
# │   │   │       └── [m=6.735,s_mag=0.316,v_imag=0.0]
# │   │   └── [m=24.722,s_mag=0.798,v_imag=36.772]
# │   │       ├── [m=22.702,s_mag=0.712,v_imag=63.185]
# │   │       │   ├── [m=11.959,s_mag=0.041,v_imag=0.0]
# │   │       │   └── [m=11.958,s_mag=0.161,v_imag=0.0]
# │   │       └── [m=2.505,s_mag=0.81,v_imag=63.178]
# │   │           ├── [m=1.336,s_mag=0.511,v_imag=0.0]
# │   │           └── [m=1.336,s_mag=0.545,v_imag=0.0]
# │   └── [m=110.079,s_mag=0.839,v_imag=42.562]
# │       ├── [m=94.794,s_mag=0.722,v_imag=28.899]
# │       │   ├── [m=88.849,s_mag=0.638,v_imag=3.287]
# │       │   │   ├── [m=87.159,s_mag=0.701,v_imag=10.977]
# │       │   │   │   ├── [m=84.897,s_mag=0.722,v_imag=30.941]
# │       │   │   │   │   ├── [m=44.767,s_mag=0.176,v_imag=0.0]
# │       │   │   │   │   └── [m=44.766,s_mag=0.081,v_imag=0.0]
# │       │   │   │   └── [m=3.338,s_mag=0.711,v_imag=30.803]
# │       │   │   │       ├── [m=1.758,s_mag=0.148,v_imag=0.0]
# │       │   │   │       └── [m=1.758,s_mag=0.023,v_imag=0.0]
# │       │   │   └── [m=2.72,s_mag=0.717,v_imag=41.884]
# │       │   │       ├── [m=1.434,s_mag=0.051,v_imag=0.0]
# │       │   │       └── [m=1.433,s_mag=0.152,v_imag=0.0]
# │       │   └── [m=7.238,s_mag=0.845,v_imag=45.087]
# │       │       ├── [m=3.893,s_mag=0.48,v_imag=0.0]
# │       │       └── [m=3.892,s_mag=0.676,v_imag=0.0]
# │       └── [m=19.42,s_mag=0.863,v_imag=24.357]
# │           ├── [m=17.297,s_mag=0.785,v_imag=50.635]
# │           │   ├── [m=9.195,s_mag=0.453,v_imag=0.0]
# │           │   └── [m=9.195,s_mag=0.272,v_imag=0.0]
# │           └── [m=2.736,s_mag=0.786,v_imag=50.107]
# │               ├── [m=1.455,s_mag=0.466,v_imag=0.0]
# │               └── [m=1.454,s_mag=0.21,v_imag=0.0]
# └── [m=97.345,s_mag=0.837,v_imag=57.727]
#     ├── [m=82.807,s_mag=0.709,v_imag=23.545]
#     │   ├── [m=79.721,s_mag=0.683,v_imag=5.894]
#     │   │   ├── [m=78.114,s_mag=0.739,v_imag=33.327]
#     │   │   │   ├── [m=41.272,s_mag=0.25,v_imag=0.0]
#     │   │   │   └── [m=41.264,s_mag=0.101,v_imag=0.0]
#     │   │   └── [m=2.592,s_mag=0.745,v_imag=33.378]
#     │   │       ├── [m=1.37,s_mag=0.278,v_imag=0.0]
#     │   │       └── [m=1.37,s_mag=0.222,v_imag=0.0]
#     │   └── [m=4.082,s_mag=0.807,v_imag=38.971]
#     │       ├── [m=2.179,s_mag=0.464,v_imag=0.0]
#     │       └── [m=2.178,s_mag=0.364,v_imag=0.0]
#     └── [m=18.361,s_mag=0.741,v_imag=62.639]
#         ├── [m=9.705,s_mag=0.248,v_imag=0.0]
#         └── [m=9.701,s_mag=0.12,v_imag=0.0]

# %% [markdown]
# ## Zero spin, No mass sort

# %%
fileloc = './sp_Z_sm_0/'
files = glob.glob(fileloc + '/*.pkl')
[print(f) for f in files];
# Out:
# ./sp_Z_sm_0/output_10.pkl
# ./sp_Z_sm_0/output_9.pkl
# ./sp_Z_sm_0/output_8.pkl
# ./sp_Z_sm_0/output_5.pkl
# ./sp_Z_sm_0/output_4.pkl
# ./sp_Z_sm_0/output_6.pkl
# ./sp_Z_sm_0/output_7.pkl
# ./sp_Z_sm_0/output_3.pkl
# ./sp_Z_sm_0/output_2.pkl
# ./sp_Z_sm_0/output_1.pkl

# %%
spZsm0_mass = []
spZsm0_spin = []
spZsm0_vel = []
spZsm0_LargestBHs = []
for fname in files:
    with open(fname,'rb') as f:
        params,seeds,all_gcs = pickle.load(f)
        
    #These files are BIG. Only do one at a time
    for gc in all_gcs:
        bhs = gc.ejected+gc.BHs
        spZsm0_mass.extend([b.m for b in bhs]) 
        spZsm0_spin.extend([b.s_mag for b in bhs])
        spZsm0_vel.extend([np.sqrt(np.sum(np.square(b.v))) for b in bhs])
        maxi = np.argmax([b.m for b in bhs])
        spZsm0_LargestBHs.append(bhs[maxi])
    del all_gcs

# %%
n,_,_=plt.hist(spZsm0_mass,bins='auto',density=True)
plt.title('BH Final Mass distribution')
plt.xlabel('BH mass [M_sun]')
plt.show()

# %%
n,_,_=plt.hist(spZsm0_spin,bins='auto',density=True)
plt.title('BH Final Spin distribution')
plt.xlabel('Dimentionless BH spin')
plt.show()

# %%
n,_,_=plt.hist(spZsm0_vel,bins='auto',density=True)
plt.title('BH Final velocity')
plt.xlabel('Velocity [km/s]')
plt.show()

# %%
maxi = np.argmax([b.m for b in spZsm0_LargestBHs])
print(spZsm0_LargestBHs[maxi],'\n')
spZsm0_LargestBHs[maxi].parents[0].printTree(params=['m','s_mag','v_imag'])
spZsm0_LargestBHs[maxi].parents[1].printTree(params=['m','s_mag','v_imag'])
# Out:
# [M:516.275,S_mag:0.839,v_mag:3027.099,v_imag:3027.099,t:1071823.267,t_i:1071823.267]
#
# [m=321.375,s_mag=0.919,v_imag=56.103]
# ├── [m=178.092,s_mag=0.84,v_imag=48.988]
# │   ├── [m=99.98,s_mag=0.63,v_imag=1.999]
# │   │   ├── [m=98.004,s_mag=0.687,v_imag=0.315]
# │   │   │   ├── [m=51.499,s_mag=0.0,v_imag=0.0]
# │   │   │   └── [m=51.492,s_mag=0.0,v_imag=0.0]
# │   │   └── [m=3.116,s_mag=0.687,v_imag=0.315]
# │   │       ├── [m=1.637,s_mag=0.0,v_imag=0.0]
# │   │       └── [m=1.637,s_mag=0.0,v_imag=0.0]
# │   └── [m=91.067,s_mag=0.611,v_imag=1.954]
# │       ├── [m=89.456,s_mag=0.687,v_imag=0.304]
# │       │   ├── [m=47.004,s_mag=0.0,v_imag=0.0]
# │       │   └── [m=47.004,s_mag=0.0,v_imag=0.0]
# │       └── [m=2.623,s_mag=0.687,v_imag=0.304]
# │           ├── [m=1.378,s_mag=0.0,v_imag=0.0]
# │           └── [m=1.378,s_mag=0.0,v_imag=0.0]
# └── [m=176.511,s_mag=0.873,v_imag=50.713]
#     ├── [m=97.335,s_mag=0.687,v_imag=0.304]
#     │   ├── [m=51.144,s_mag=0.0,v_imag=0.0]
#     │   └── [m=51.144,s_mag=0.0,v_imag=0.0]
#     └── [m=93.803,s_mag=0.687,v_imag=0.304]
#         ├── [m=49.288,s_mag=0.0,v_imag=0.0]
#         └── [m=49.288,s_mag=0.0,v_imag=0.0]
#
# [m=233.305,s_mag=0.915,v_imag=43.616]
# ├── [m=138.451,s_mag=0.867,v_imag=63.513]
# │   ├── [m=80.246,s_mag=0.687,v_imag=0.353]
# │   │   ├── [m=42.174,s_mag=0.0,v_imag=0.0]
# │   │   └── [m=42.155,s_mag=0.0,v_imag=0.0]
# │   └── [m=69.538,s_mag=0.687,v_imag=0.353]
# │       ├── [m=36.546,s_mag=0.0,v_imag=0.0]
# │       └── [m=36.53,s_mag=0.0,v_imag=0.0]
# └── [m=117.187,s_mag=0.87,v_imag=63.419]
#     ├── [m=81.099,s_mag=0.687,v_imag=0.312]
#     │   ├── [m=42.615,s_mag=0.0,v_imag=0.0]
#     │   └── [m=42.611,s_mag=0.0,v_imag=0.0]
#     └── [m=44.783,s_mag=0.687,v_imag=0.312]
#         ├── [m=23.532,s_mag=0.0,v_imag=0.0]
#         └── [m=23.53,s_mag=0.0,v_imag=0.0]

# %% [markdown]
# ## Zero spin, Yes mass sort

# %%
fileloc = './sp_Z_sm_1/'
files = glob.glob(fileloc + '/*.pkl')
[print(f) for f in files];
# Out:
# ./sp_Z_sm_1/output_10.pkl
# ./sp_Z_sm_1/output_9.pkl
# ./sp_Z_sm_1/output_8.pkl
# ./sp_Z_sm_1/output_5.pkl
# ./sp_Z_sm_1/output_4.pkl
# ./sp_Z_sm_1/output_6.pkl
# ./sp_Z_sm_1/output_7.pkl
# ./sp_Z_sm_1/output_3.pkl
# ./sp_Z_sm_1/output_2.pkl
# ./sp_Z_sm_1/output_1.pkl

# %%
spZsm1_mass = []
spZsm1_spin = []
spZsm1_vel = []
spZsm1_LargestBHs = []
for fname in files:
    with open(fname,'rb') as f:
        params,seeds,all_gcs = pickle.load(f)
        
    #These files are BIG. Only do one at a time
    for gc in all_gcs:
        bhs = gc.ejected+gc.BHs
        spZsm1_mass.extend([b.m for b in bhs]) 
        spZsm1_spin.extend([b.s_mag for b in bhs])
        spZsm1_vel.extend([np.sqrt(np.sum(np.square(b.v))) for b in bhs])
        maxi = np.argmax([b.m for b in bhs])
        spZsm1_LargestBHs.append(bhs[maxi])
    del all_gcs

# %%
n,_,_=plt.hist(spZsm1_mass,bins='auto',density=True)
plt.title('BH Final Mass distribution')
plt.xlabel('BH mass [M_sun]')
plt.show()

# %%
n,_,_=plt.hist(spZsm1_spin,bins='auto',density=True)
plt.title('BH Final Spin distribution')
plt.xlabel('Dimentionless BH spin')
plt.show()

# %%
n,_,_=plt.hist(spZsm1_vel,bins='auto',density=True)
plt.title('BH Final velocity')
plt.xlabel('Velocity [km/s]')
plt.show()

# %%
maxi = np.argmax([b.m for b in spZsm1_LargestBHs])
spZsm1_LargestBHs[maxi].printTree(params=['m','s_mag','v_imag'])
# Out:
# [m=454.353,s_mag=0.806,v_imag=2136.523]
# ├── [m=302.792,s_mag=0.822,v_imag=65.419]
# │   ├── [m=162.437,s_mag=0.864,v_imag=59.518]
# │   │   ├── [m=102.337,s_mag=0.739,v_imag=30.447]
# │   │   │   ├── [m=97.319,s_mag=0.687,v_imag=0.313]
# │   │   │   │   ├── [m=51.138,s_mag=0.0,v_imag=0.0]
# │   │   │   │   └── [m=51.133,s_mag=0.0,v_imag=0.0]
# │   │   │   └── [m=6.332,s_mag=0.687,v_imag=0.313]
# │   │   │       ├── [m=3.327,s_mag=0.0,v_imag=0.0]
# │   │   │       └── [m=3.327,s_mag=0.0,v_imag=0.0]
# │   │   └── [m=72.327,s_mag=0.739,v_imag=30.419]
# │   │       ├── [m=68.786,s_mag=0.687,v_imag=0.306]
# │   │       │   ├── [m=36.143,s_mag=0.0,v_imag=0.0]
# │   │       │   └── [m=36.142,s_mag=0.0,v_imag=0.0]
# │   │       └── [m=4.47,s_mag=0.687,v_imag=0.306]
# │   │           ├── [m=2.349,s_mag=0.0,v_imag=0.0]
# │   │           └── [m=2.349,s_mag=0.0,v_imag=0.0]
# │   └── [m=161.685,s_mag=0.888,v_imag=36.75]
# │       ├── [m=149.951,s_mag=0.847,v_imag=43.601]
# │       │   ├── [m=82.19,s_mag=0.638,v_imag=3.047]
# │       │   │   ├── [m=80.481,s_mag=0.687,v_imag=0.307]
# │       │   │   │   ├── [m=42.289,s_mag=0.0,v_imag=0.0]
# │       │   │   │   └── [m=42.287,s_mag=0.0,v_imag=0.0]
# │       │   │   └── [m=2.654,s_mag=0.687,v_imag=0.307]
# │       │   │       ├── [m=1.394,s_mag=0.0,v_imag=0.0]
# │       │   │       └── [m=1.394,s_mag=0.0,v_imag=0.0]
# │       │   └── [m=79.145,s_mag=0.638,v_imag=3.05]
# │       │       ├── [m=77.499,s_mag=0.687,v_imag=0.305]
# │       │       │   ├── [m=40.722,s_mag=0.0,v_imag=0.0]
# │       │       │   └── [m=40.721,s_mag=0.0,v_imag=0.0]
# │       │       └── [m=2.556,s_mag=0.687,v_imag=0.305]
# │       │           ├── [m=1.343,s_mag=0.0,v_imag=0.0]
# │       │           └── [m=1.343,s_mag=0.0,v_imag=0.0]
# │       └── [m=15.517,s_mag=0.818,v_imag=46.659]
# │           ├── [m=13.39,s_mag=0.687,v_imag=0.319]
# │           │   ├── [m=7.036,s_mag=0.0,v_imag=0.0]
# │           │   └── [m=7.035,s_mag=0.0,v_imag=0.0]
# │           └── [m=2.658,s_mag=0.687,v_imag=0.319]
# │               ├── [m=1.397,s_mag=0.0,v_imag=0.0]
# │               └── [m=1.396,s_mag=0.0,v_imag=0.0]
# └── [m=181.898,s_mag=0.851,v_imag=44.341]
#     ├── [m=170.063,s_mag=0.803,v_imag=57.909]
#     │   ├── [m=101.762,s_mag=0.589,v_imag=3.984]
#     │   │   ├── [m=100.161,s_mag=0.687,v_imag=0.308]
#     │   │   │   ├── [m=52.63,s_mag=0.0,v_imag=0.0]
#     │   │   │   └── [m=52.627,s_mag=0.0,v_imag=0.0]
#     │   │   └── [m=2.689,s_mag=0.687,v_imag=0.308]
#     │   │       ├── [m=1.413,s_mag=0.0,v_imag=0.0]
#     │   │       └── [m=1.413,s_mag=0.0,v_imag=0.0]
#     │   └── [m=79.394,s_mag=0.644,v_imag=4.018]
#     │       ├── [m=77.677,s_mag=0.687,v_imag=0.305]
#     │       │   ├── [m=40.815,s_mag=0.0,v_imag=0.0]
#     │       │   └── [m=40.815,s_mag=0.0,v_imag=0.0]
#     │       └── [m=2.634,s_mag=0.687,v_imag=0.305]
#     │           ├── [m=1.384,s_mag=0.0,v_imag=0.0]
#     │           └── [m=1.384,s_mag=0.0,v_imag=0.0]
#     └── [m=15.313,s_mag=0.805,v_imag=61.757]
#         ├── [m=11.389,s_mag=0.687,v_imag=0.552]
#         │   ├── [m=5.989,s_mag=0.0,v_imag=0.0]
#         │   └── [m=5.98,s_mag=0.0,v_imag=0.0]
#         └── [m=4.715,s_mag=0.687,v_imag=0.551]
#             ├── [m=2.48,s_mag=0.0,v_imag=0.0]
#             └── [m=2.476,s_mag=0.0,v_imag=0.0]

# %% [markdown]
# ## Combining data

# %%
m_low = 50
n,_,_=plt.hist([s for s in spZsm0_mass if s>m_low],bins='auto',
               density=True,histtype='step',label='Spin=Zero ; Birth order=No',color='b')
n,_,_=plt.hist([s for s in spZsm1_mass if s>m_low],bins='auto',
               density=True,histtype='step',label='Spin=Zero ; Birth order=Yes',color='c')
n,_,_=plt.hist([s for s in spUsm0_mass if s>m_low],bins='auto',
               density=True,histtype='step',label='Spin=Uniform ; Birth order=No',color='r')
n,_,_=plt.hist([s for s in spUsm1_mass if s>m_low],bins='auto',
               density=True,histtype='step',label='Spin=Uniform ; Birth order=Yes',color='orange')
plt.title('BH Final Mass distribution [M>50]')
plt.xlabel('BH mass [M_sun]')
plt.ylim(0,max(n)*1.1)
plt.legend()
plt.show()

# %%
m_low = 200
n,_,_=plt.hist([s for s in spZsm0_mass if s>m_low],bins='auto',
               density=True,histtype='step',label='Spin=Zero ; Birth order=No',color='b')
n,_,_=plt.hist([s for s in spZsm1_mass if s>m_low],bins='auto',
               density=True,histtype='step',label='Spin=Zero ; Birth order=Yes',color='c')
n,_,_=plt.hist([s for s in spUsm0_mass if s>m_low],bins='auto',
               density=True,histtype='step',label='Spin=Uniform ; Birth order=No',color='r')
n,_,_=plt.hist([s for s in spUsm1_mass if s>m_low],bins='auto',
               density=True,histtype='step',label='Spin=Uniform ; Birth order=Yes',color='orange')
plt.title('BH Final Mass distribution [M>200]')
plt.xlabel('BH mass [M_sun]')
plt.ylim(0,max(n)*1.1)
plt.legend()
plt.show()

# %%
print('Spin=Zero; Birth order=No; Above 300 M = '+str(round(100*len([m for m in spZsm0_mass if m>300])/len(spZsm0_mass),5))+'%')
print('Spin=Zero; Birth order=Yes; Above 300 M = '+str(round(100*len([m for m in spZsm1_mass if m>300])/len(spZsm0_mass),5))+'%')
print('Spin=Uniform; Birth order=No; Above 300 M = '+str(round(100*len([m for m in spUsm0_mass if m>300])/len(spZsm0_mass),5))+'%')
print('Spin=Uniform; Birth order=Yes; Above 300 M = '+str(round(100*len([m for m in spUsm1_mass if m>300])/len(spZsm0_mass),5))+'%')
# Out:
# Spin=Zero; Birth order=No; Above 300 M = 0.02732%
# Spin=Zero; Birth order=Yes; Above 300 M = 0.02681%
# Spin=Uniform; Birth order=No; Above 300 M = 0.00024%
# Spin=Uniform; Birth order=Yes; Above 300 M = 0.00051%

# %%
n,_,_=plt.hist(spZsm0_spin,bins='auto',
               density=True,histtype='step',label='Spin=Zero ; Birth order=No',color='b')
n,_,_=plt.hist(spZsm1_spin,bins='auto',
               density=True,histtype='step',label='Spin=Zero ; Birth order=Yes',color='c')
n,_,_=plt.hist(spUsm0_spin,bins='auto',
               density=True,histtype='step',label='Spin=Uniform ; Birth order=No',color='r')
n,_,_=plt.hist(spUsm1_spin,bins='auto',
               density=True,histtype='step',label='Spin=Uniform ; Birth order=Yes',color='orange')
#n,_,_=plt.hist(spZsm1_spin,bins='auto',density=True)
plt.title('BH Final Spin distribution')
plt.xlabel('Dimentionless BH spin')
plt.legend(loc='upper left')
plt.show()

# %%
n,_,_=plt.hist(spZsm0_vel,bins='auto',
               density=True,histtype='step',label='Spin=Zero ; Birth order=No',color='b')
n,_,_=plt.hist(spZsm1_vel,bins='auto',
               density=True,histtype='step',label='Spin=Zero ; Birth order=Yes',color='c')
n,_,_=plt.hist(spUsm0_vel,bins='auto',
               density=True,histtype='step',label='Spin=Uniform ; Birth order=No',color='r')
n,_,_=plt.hist(spUsm1_vel,bins='auto',
               density=True,histtype='step',label='Spin=Uniform ; Birth order=Yes',color='orange')
plt.title('BH Final velocity')
plt.xlabel('Velocity [km/s]')
plt.ylim(0,max(n)*1.1)
plt.legend()
plt.show()
