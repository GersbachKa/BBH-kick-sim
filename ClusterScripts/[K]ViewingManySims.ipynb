# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %load_ext autoreload
# %autoreload 2

import numpy as np
from matplotlib import pyplot as plt

import sys
sys.path.append('..')
from BBH_kick_sim import Simulator

import pickle
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open('./testout.pkl','rb') as f:
    params,seeds,GCs = pickle.load(f)

# %%
allBHs = []
for gc in GCs:
    simBH = gc.BHs + gc.ejected
    allBHs = allBHs+simBH
print(len(allBHs))
# Out:
# 28940

# %%
mall = [bh.m for bh in allBHs]
n,_,_=plt.hist(mall,bins='auto',density=True)
plt.title('BH Final Mass distribution')
plt.xlabel('BH mass [M_sun]')
maxBH = params['bh_mass_frac']*params['max_star']
plt.vlines(maxBH,0,max(n),linestyles='dashed',colors='r',label='BH mass gap')
plt.legend()
plt.show()

# %%
sall = [bh.s_mag for bh in allBHs]
n,_,_=plt.hist(sall,bins='auto',density=True)
plt.title('BH Final Spin distribution')
plt.xlabel('BH spin [M_sun]')
#maxBH = params['bh_mass_frac']*params['max_star']
#plt.vlines(maxBH,0,max(n),linestyles='dashed',colors='r',label='BH mass gap')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
imax = np.argmax(mall)
bigbh = allBHs[imax]
bigbh.printTree(params=['m','v_imag','s','s_mag'])
# Out:
# [m=362.059,s=[-0.115 -0.016  0.902],s_mag=0.91,v_imag=757.931]
# ├── [m=203.15,s=[-0.577  0.005  0.667],s_mag=0.881,v_imag=28.927]
# │   ├── [m=184.911,s=[-0.578  0.396  0.438],s_mag=0.826,v_imag=54.31]
# │   │   ├── [m=100.077,s=[-0.339  0.018  0.476],s_mag=0.585,v_imag=4.403]
# │   │   │   ├── [m=98.539,s=[-0.036  0.476  0.494],s_mag=0.687,v_imag=0.307]
# │   │   │   │   ├── [m=51.777,s=[0. 0. 0.],s_mag=0.0,v_imag=0.0]
# │   │   │   │   └── [m=51.776,s=[-0. -0.  0.],s_mag=0.0,v_imag=0.0]
# │   │   │   └── [m=2.597,s=[-0.195  0.046  0.657],s_mag=0.687,v_imag=0.307]
# │   │   │       ├── [m=1.364,s=[ 0. -0.  0.],s_mag=0.0,v_imag=0.0]
# │   │   │       └── [m=1.364,s=[-0. -0.  0.],s_mag=0.0,v_imag=0.0]
# │   │   └── [m=97.937,s=[-0.385  0.157  0.411],s_mag=0.585,v_imag=4.399]
# │   │       ├── [m=96.432,s=[ 0.052 -0.079  0.68 ],s_mag=0.687,v_imag=0.304]
# │   │       │   ├── [m=50.669,s=[0. 0. 0.],s_mag=0.0,v_imag=0.0]
# │   │       │   └── [m=50.669,s=[0. 0. 0.],s_mag=0.0,v_imag=0.0]
# │   │       └── [m=2.542,s=[-0.258  0.221  0.597],s_mag=0.687,v_imag=0.304]
# │   │           ├── [m=1.335,s=[-0. -0.  0.],s_mag=0.0,v_imag=0.0]
# │   │           └── [m=1.335,s=[0. 0. 0.],s_mag=0.0,v_imag=0.0]
# │   └── [m=23.897,s=[0.354 0.42  0.623],s_mag=0.831,v_imag=58.912]
# │       ├── [m=19.736,s=[-0.005 -0.013  0.686],s_mag=0.687,v_imag=0.377]
# │       │   ├── [m=10.373,s=[ 0. -0.  0.],s_mag=0.0,v_imag=0.0]
# │       │   └── [m=10.367,s=[-0. -0.  0.],s_mag=0.0,v_imag=0.0]
# │       └── [m=5.186,s=[-0.427  0.35   0.408],s_mag=0.687,v_imag=0.377]
# │           ├── [m=2.726,s=[-0.  0.  0.],s_mag=0.0,v_imag=0.0]
# │           └── [m=2.724,s=[-0.  0.  0.],s_mag=0.0,v_imag=0.0]
# └── [m=192.557,s=[ 0.01  -0.067  0.913],s_mag=0.916,v_imag=23.142]
#     ├── [m=175.834,s=[0.005 0.011 0.88 ],s_mag=0.88,v_imag=65.264]
#     │   ├── [m=95.544,s=[0.005 0.005 0.686],s_mag=0.687,v_imag=0.307]
#     │   │   ├── [m=50.204,s=[ 0. -0.  0.],s_mag=0.0,v_imag=0.0]
#     │   │   └── [m=50.202,s=[ 0. -0.  0.],s_mag=0.0,v_imag=0.0]
#     │   └── [m=95.401,s=[ 0.04  -0.003  0.685],s_mag=0.687,v_imag=0.307]
#     │       ├── [m=50.129,s=[0. 0. 0.],s_mag=0.0,v_imag=0.0]
#     │       └── [m=50.127,s=[ 0. -0.  0.],s_mag=0.0,v_imag=0.0]
#     └── [m=22.605,s=[0.266 0.362 0.698],s_mag=0.83,v_imag=64.999]
#         ├── [m=18.866,s=[0.001 0.001 0.686],s_mag=0.687,v_imag=0.311]
#         │   ├── [m=9.914,s=[ 0. -0.  0.],s_mag=0.0,v_imag=0.0]
#         │   └── [m=9.913,s=[0. 0. 0.],s_mag=0.0,v_imag=0.0]
#         └── [m=4.676,s=[0.308 0.014 0.613],s_mag=0.687,v_imag=0.311]
#             ├── [m=2.457,s=[-0. -0.  0.],s_mag=0.0,v_imag=0.0]
#             └── [m=2.457,s=[-0.  0.  0.],s_mag=0.0,v_imag=0.0]
